# %%
import pandas as pd
import os

pd.options.display.float_format = '{:1.2f}'.format
pd.options.display.max_columns = None

# %%
files = 0
for file in os.listdir("raw_listing"):
    files += 1
print(f"Number of listing files: {files}")
# Out:
# Number of listing files: 27

# %%
df = pd.read_csv(f"raw_listing/CRMLSListing202502.csv", encoding='latin-1')

print('listing data:')
df.head()
# Out:
# listing data:
#    OriginalListPrice  ListingKey              ListAgentEmail CloseDate  \
# 0         1100000.00  1108426966  Andrew.Liberty@compass.com       NaN
# 1          595500.00  1108426965  williamramsey760@gmail.com       NaN
# 2            3500.00  1108426536      omegafunding@yahoo.com       NaN
# 3          995000.00  1108426334           Jessica@native.us       NaN
# 4         1485000.00  1108425215    nickiwanderson@gmail.com       NaN
#
#    ClosePrice ListAgentFirstName ListAgentLastName  Latitude  Longitude  \
# 0         NaN          Andrew R.           Liberty     34.11    -118.25
# 1         NaN            William            Ramsey     34.18    -116.07
# 2         NaN             Vartan         Missirian     34.13    -117.91
# 3         NaN            Jessica             Foote     33.61    -117.19
# 4         NaN              Nicki          Anderson     35.14    -120.56
#
#             UnparsedAddress       PropertyType  LivingArea  ListPrice  \
# 0         3170 Larga Avenue  ResidentialIncome     1196.00 1100000.00
# 1      72772 Nandina Street        Residential     1712.00  595500.00
# 2  300 N San Gabriel Avenue   ResidentialLease     1380.00    3500.00
# 3     26891 Aubrieta Street        Residential     3863.00  995000.00
# 4            608 Stagecoach        Residential     2411.00 1485000.00
#
#    DaysOnMarket            ListOfficeName BuyerOfficeName  \
# 0            29                   Compass             NaN
# 1             0  Sharon Rose Realty, Inc.             NaN
# 2             0           Legend Realtors             NaN
# 3             0                    Native             NaN
# 4             0              Comet Realty             NaN
#
#            CoListOfficeName  ListAgentFullName CoListAgentFirstName  \
# 0            Secret HQ, Inc  Andrew R. Liberty                  Lek
# 1  Sharon Rose Realty, Inc.     William Ramsey                 Luis
# 2           Legend Realtors   Vartan Missirian                Alina
# 3                    Native      Jessica Foote               Reanne
# 4              Comet Realty     Nicki Anderson                Brian
#
#   CoListAgentLastName BuyerAgentMlsId BuyerAgentFirstName BuyerAgentLastName  \
# 0        Adjchavanich             NaN                 NaN                NaN
# 1            Carrillo             NaN                 NaN                NaN
# 2           Missirian             NaN                 NaN                NaN
# 3              Mosley             NaN                 NaN                NaN
# 4                Gust             NaN                 NaN                NaN
#
#    FireplacesTotal AssociationFeeFrequency  AboveGradeFinishedArea  \
# 0              NaN                     NaN                     NaN
# 1              NaN                     NaN                     NaN
# 2              NaN                     NaN                     NaN
# 3              NaN                 Monthly                     NaN
# 4              NaN                 Monthly                     NaN
#
#    ListingKeyNumeric                        MLSAreaMajor  TaxAnnualAmount  \
# 0         1108426966                       606 - Atwater              NaN
# 1         1108426965              DC710 - Desert Heights              NaN
# 2         1108426536                         607 - Azusa              NaN
# 3         1108426334  SRCAR - Southwest Riverside County              NaN
# 4         1108425215                  AG-East of Hwy 101              NaN
#
#     CountyOrParish     PropertyType.1 MlsStatus ElementarySchool  \
# 0      Los Angeles  ResidentialIncome    Active              NaN
# 1   San Bernardino        Residential    Active              NaN
# 2      Los Angeles   ResidentialLease    Active              NaN
# 3        Riverside        Residential    Active              NaN
# 4  San Luis Obispo        Residential    Active           Branch
#
#   ListAgentFirstName.1 AttachedGarageYN  ParkingTotal      BuilderName  \
# 0            Andrew R.            False          0.00              NaN
# 1              William             True          2.00              NaN
# 2               Vartan              NaN          1.00              NaN
# 3              Jessica             True          6.00              NaN
# 4                Nicki             True          3.00  Midland Pacific
#
#          PropertySubType  LotSizeAcres   SubdivisionName BuyerOfficeAOR  \
# 0                    NaN          0.12               NaN            NaN
# 1  SingleFamilyResidence          2.27  Not Applicable-1            NaN
# 2                 Duplex       6900.00    Not Applicable            NaN
# 3  SingleFamilyResidence          0.16               NaN            NaN
# 4  SingleFamilyResidence          0.47               NaN            NaN
#
#    YearBuilt  DaysOnMarket.1  StreetNumberNumeric  LivingArea.1    ListingId  \
# 0    1928.00              29              3170.00       1196.00     25508805
# 1    2006.00               0             72772.00       1712.00  219126159PS
# 2    1989.00               0               300.00       1380.00     P1-21172
# 3    2005.00               0             26891.00       3863.00   SW25044469
# 4    2001.00               0               608.00       2411.00   PI25050653
#
#    BathroomsTotalInteger           City  TaxYear  BuildingAreaTotal  \
# 0                   2.00    Los Angeles      NaN            1196.00
# 1                   2.00       29 Palms      NaN                NaN
# 2                   2.00          Azusa      NaN                NaN
# 3                   5.00       Murrieta      NaN                NaN
# 4                   3.00  Arroyo Grande      NaN                NaN
#
#    BedroomsTotal ContractStatusChangeDate  Longitude.1  \
# 0           2.00               2025-02-07      -118.25
# 1           3.00               2025-02-25      -116.07
# 2           3.00               2025-02-27      -117.91
# 3           4.00               2025-02-26      -117.19
# 4           3.00               2025-02-27      -120.56
#
#    ElementarySchoolDistrict CoBuyerAgentFirstName PurchaseContractDate  \
# 0                       NaN                   NaN                  NaN
# 1                       NaN                   NaN                  NaN
# 2                       NaN                   NaN                  NaN
# 3                       NaN                   NaN                  NaN
# 4                       NaN                   NaN                  NaN
#
#   ListingContractDate  BelowGradeFinishedArea BusinessType  Latitude.1  \
# 0          2025-02-07                     NaN          NaN       34.11
# 1          2025-02-25                     NaN          NaN       34.18
# 2          2025-02-27                     NaN          NaN       34.13
# 3          2025-02-26                     NaN          NaN       33.61
# 4          2025-02-27                     NaN          NaN       35.14
#
#    ListPrice.1 StateOrProvince  CoveredSpaces MiddleOrJuniorSchool  \
# 0   1100000.00              CA            NaN                  NaN
# 1    595500.00              CA            NaN                  NaN
# 2      3500.00              CA            NaN                  NaN
# 3    995000.00              CA            NaN                  NaN
# 4   1485000.00              CA            NaN                  NaN
#
#   FireplaceYN  Stories HighSchool      Levels ListAgentLastName.1 CloseDate.1  \
# 0         NaN      NaN        NaN  MultiSplit             Liberty         NaN
# 1        True     1.00        NaN         One              Ramsey         NaN
# 2        True     1.00        NaN         One           Missirian         NaN
# 3        True     2.00        NaN         Two               Foote         NaN
# 4        True      NaN        NaN  MultiSplit            Anderson         NaN
#
#   LotSizeDimensions  LotSizeArea  MainLevelBedrooms NewConstructionYN  \
# 0               NaN      5413.00                NaN             False
# 1               NaN     99011.00                NaN             False
# 2               NaN      6900.00               3.00               NaN
# 3               NaN      6970.00               1.00             False
# 4               NaN         0.47               1.00             False
#
#    GarageSpaces HighSchoolDistrict PostalCode BuyerOfficeName.1  \
# 0           NaN                NaN      90039               NaN
# 1          2.00                NaN      92277               NaN
# 2          0.00                NaN      91702               NaN
# 3          4.00           Murrieta      92562               NaN
# 4          3.00  Lucia Mar Unified      93420               NaN
#
#    AssociationFee  LotSizeSquareFeet  MiddleOrJuniorSchoolDistrict  \
# 0             NaN            5413.00                           NaN
# 1             NaN           99011.00                           NaN
# 2            0.00       300564000.00                           NaN
# 3          227.00            6970.00                           NaN
# 4           72.00           20473.20                           NaN
#
#           UnparsedAddress.1
# 0         3170 Larga Avenue
# 1      72772 Nandina Street
# 2  300 N San Gabriel Avenue
# 3     26891 Aubrieta Street
# 4            608 Stagecoach

# %%
df.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'CloseDate',
#        'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName', 'Latitude',
#        'Longitude', 'UnparsedAddress', 'PropertyType', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'PropertyType.1', 'MlsStatus',
#        'ElementarySchool', 'ListAgentFirstName.1', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1',
#        'StreetNumberNumeric', 'LivingArea.1', 'ListingId',
#        'BathroomsTotalInteger', 'City', 'TaxYear', 'BuildingAreaTotal',
#        'BedroomsTotal', 'ContractStatusChangeDate', 'Longitude.1',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'Latitude.1', 'ListPrice.1', 'StateOrProvince',
#        'CoveredSpaces', 'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories',
#        'HighSchool', 'Levels', 'ListAgentLastName.1', 'CloseDate.1',
#        'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'BuyerOfficeName.1', 'AssociationFee', 'LotSizeSquareFeet',
#        'MiddleOrJuniorSchoolDistrict', 'UnparsedAddress.1'],
#       dtype='object')

# %%
df.describe()
# Out:
#        OriginalListPrice    ListingKey  ClosePrice  Latitude  Longitude  \
# count           33853.00      33983.00     2725.00  33500.00   33525.00
# mean          1183687.39 1106732686.86   652947.85     34.65    -118.49
# std           8334258.54    1441429.97  1299081.75      1.75       5.03
# min                 0.19 1054004728.00      480.00    -41.28    -123.84
# 25%            157500.00 1106466326.50     3645.00     33.76    -118.66
# 50%            674999.00 1107234029.00     8000.00     34.07    -118.14
# 75%           1250000.00 1107705449.50   940000.00     34.51    -117.29
# max         969000000.00 1108426966.00 32500000.00     43.88     329.00
#
#        LivingArea    ListPrice  DaysOnMarket  FireplacesTotal  \
# count    29545.00     33888.00      33983.00             0.00
# mean      1955.01   1096204.91          9.43              NaN
# std       1555.52   2500914.67         12.87              NaN
# min          0.00         0.19         -6.00              NaN
# 25%       1191.00    159000.00          3.00              NaN
# 50%       1622.00    674000.00          8.00              NaN
# 75%       2296.00   1250000.00         14.00              NaN
# max      84500.00 177000000.00       1101.00              NaN
#
#        AboveGradeFinishedArea  ListingKeyNumeric  TaxAnnualAmount  \
# count                    0.00           33983.00           236.00
# mean                      NaN      1106732686.86         14472.10
# std                       NaN         1441429.97         21595.08
# min                       NaN      1054004728.00             0.00
# 25%                       NaN      1106466326.50           305.25
# 50%                       NaN      1107234029.00          7999.00
# 75%                       NaN      1107705449.50         21379.00
# max                       NaN      1108426966.00        225597.00
#
#        ParkingTotal  LotSizeAcres  YearBuilt  DaysOnMarket.1  \
# count      31870.00      30895.00   31076.00        33983.00
# mean           2.64         27.40    1978.47            9.43
# std            8.46       2485.39      28.42           12.87
# min          -30.00          0.00    1776.00           -6.00
# 25%            1.00          0.12    1959.00            3.00
# 50%            2.00          0.17    1979.00            8.00
# 75%            3.00          0.41    2001.00           14.00
# max          650.00     414293.00    2028.00         1101.00
#
#        StreetNumberNumeric  LivingArea.1  BathroomsTotalInteger  TaxYear  \
# count             33810.00      29545.00               31126.00    31.00
# mean              22895.72       1955.01                   2.54  2023.97
# std              734313.50       1555.52                   1.75     0.60
# min                   0.00          0.00                   0.00  2022.00
# 25%                 761.00       1191.00                   2.00  2024.00
# 50%                2742.00       1622.00                   2.00  2024.00
# 75%               10743.50       2296.00                   3.00  2024.00
# max            61517416.00      84500.00                  57.00  2025.00
#
#        BuildingAreaTotal  BedroomsTotal  Longitude.1  \
# count            5676.00       29685.00     33525.00
# mean             3269.62           3.16      -118.49
# std              7827.51           1.70         5.03
# min                 0.00           0.00      -123.84
# 25%              1253.00           2.00      -118.66
# 50%              1953.00           3.00      -118.14
# 75%              3392.50           4.00      -117.29
# max            449040.00          78.00       329.00
#
#        ElementarySchoolDistrict  BelowGradeFinishedArea  Latitude.1  \
# count                      0.00                  131.00    33500.00
# mean                        NaN                   99.94       34.65
# std                         NaN                  357.64        1.75
# min                         NaN                    0.00      -41.28
# 25%                         NaN                    0.00       33.76
# 50%                         NaN                    0.00       34.07
# 75%                         NaN                    0.00       34.51
# max                         NaN                 2300.00       43.88
#
#        ListPrice.1  CoveredSpaces  Stories  LotSizeArea  MainLevelBedrooms  \
# count     33888.00           0.00 24478.00     31013.00           14738.00
# mean    1096204.91            NaN     1.37     56327.24               1.93
# std     2500914.67            NaN     0.48    966143.39               1.48
# min           0.19            NaN     1.00         0.00               0.00
# 25%      159000.00            NaN     1.00      5000.00               1.00
# 50%      674000.00            NaN     1.00      7349.00               2.00
# 75%     1250000.00            NaN     2.00     14785.00               3.00
# max   177000000.00            NaN     2.00 117432626.96              33.00
#
#        GarageSpaces  AssociationFee  LotSizeSquareFeet  \
# count      27270.00        22816.00           30980.00
# mean           1.73          218.33          382129.32
# std            2.78          525.80        19456004.96
# min            0.00            0.00               0.00
# 25%            1.00            0.00            5250.00
# 50%            2.00            0.00            7502.00
# 75%            2.00          345.00           17524.25
# max          400.00        26896.00      2087220960.00
#
#        MiddleOrJuniorSchoolDistrict
# count                          0.00
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN

# %%
merged_df = None
folder_path = "raw_listing"
for file in os.listdir(folder_path):
    df = pd.read_csv(f"{folder_path}/{file}", encoding='latin-1')
    Residential_df = df[df['PropertyType'] == 'Residential']
    if merged_df is None:
        merged_df = df
        merged_residential_df = Residential_df
    else:
        merged_df = pd.concat([merged_df, df])
        merged_residential_df = pd.concat([merged_residential_df, Residential_df])

# %%
merged_df.describe()
# Out:
#        OriginalListPrice    ListingKey   ClosePrice  Latitude  Longitude  \
# count          849641.00     852963.00    239043.00 741053.00  741756.00
# mean          1050528.89 1104976762.58    784176.72     34.52    -118.36
# std           6391364.92   29955382.59   3418229.08      1.88       3.91
# min                 0.00  421654881.00         0.00   -117.47    -159.52
# 25%             85000.00 1077478681.50      5000.00     33.76    -118.51
# 50%            639888.00 1104356715.00    570000.00     34.05    -118.09
# 75%           1150000.00 1127370000.50   1030000.00     34.30    -117.29
# max        1390000000.00 1157177805.00 820000000.00    737.00     392.00
#
#         LivingArea    ListPrice  DaysOnMarket  FireplacesTotal  \
# count    746485.00    850826.00     852963.00             0.00
# mean       3160.82    983334.34         19.51              NaN
# std     1052385.32   2163150.61         28.92              NaN
# min           0.00         0.00        -58.00              NaN
# 25%        1182.00     85000.00          4.00              NaN
# 50%        1602.00    635000.00         10.00              NaN
# 75%        2236.00   1150000.00         23.00              NaN
# max   909090909.00 443650265.00       2539.00              NaN
#
#        AboveGradeFinishedArea  ListingKeyNumeric  TaxAnnualAmount  \
# count                    0.00          852963.00          6072.00
# mean                      NaN      1104976762.58         30660.17
# std                       NaN        29955382.59        967227.93
# min                       NaN       421654881.00             0.00
# 25%                       NaN      1077478681.50           118.89
# 50%                       NaN      1104356715.00          6250.00
# 75%                       NaN      1127370000.50         19623.25
# max                       NaN      1157177805.00      74460000.00
#
#        ParkingTotal  LotSizeAcres  YearBuilt  DaysOnMarket.1  \
# count     800581.00     771538.00  783489.00       852963.00
# mean           6.44        551.07    1978.41           19.51
# std         2908.37     421673.86      28.04           28.92
# min         -143.00          0.00    1776.00          -58.00
# 25%            1.00          0.12    1960.00            4.00
# 50%            2.00          0.17    1979.00           10.00
# 75%            3.00          0.39    2001.00           23.00
# max      2593669.00  370260000.00    2028.00         2539.00
#
#        StreetNumberNumeric  LivingArea.1  BathroomsTotalInteger  \
# count            849223.00     746485.00              782985.00
# mean              28219.06       3160.82                   2.50
# std             2042718.07    1052385.32                   3.04
# min                   0.00          0.00                   0.00
# 25%                 765.00       1182.00                   2.00
# 50%                2760.00       1602.00                   2.00
# 75%               10815.00       2236.00                   3.00
# max           721271024.00  909090909.00                2208.00
#
#        BuyerAgencyCompensation  TaxYear  BuildingAreaTotal  BedroomsTotal  \
# count                123519.00   869.00          136653.00      749881.00
# mean                    175.05  2023.33            3342.15           3.13
# std                    2053.69     2.65           11311.33           1.69
# min                       0.00  2004.00               0.00           0.00
# 25%                       2.00  2023.00            1219.00           2.00
# 50%                       2.50  2024.00            1870.00           3.00
# 75%                       2.50  2024.00            3211.00           4.00
# max                  200000.00  2026.00         1200000.00         149.00
#
#        Longitude.1  ElementarySchoolDistrict  BelowGradeFinishedArea  \
# count    741756.00                      0.00                 3426.00
# mean       -118.36                       NaN                   96.76
# std           3.91                       NaN                  497.11
# min        -159.52                       NaN                    0.00
# 25%        -118.51                       NaN                    0.00
# 50%        -118.09                       NaN                    0.00
# 75%        -117.29                       NaN                    0.00
# max         392.00                       NaN                17424.00
#
#        Latitude.1  ListPrice.1  CoveredSpaces   Stories  LotSizeArea  \
# count   741053.00    850826.00           0.00 632048.00    775317.00
# mean        34.52    983334.34            NaN      1.37     66426.01
# std          1.88   2163150.61            NaN      0.48   2374153.17
# min       -117.47         0.00            NaN      1.00         0.00
# 25%         33.76     85000.00            NaN      1.00      4935.00
# 50%         34.05    635000.00            NaN      1.00      7228.00
# 75%         34.30   1150000.00            NaN      2.00     13695.00
# max        737.00 443650265.00            NaN      2.00 918742280.00
#
#        MainLevelBedrooms  GarageSpaces  AssociationFee  LotSizeSquareFeet  \
# count          395045.00     691074.00       577720.00          774240.00
# mean                1.93          1.76          205.12          562127.04
# std                 5.60          3.94         2060.98        23101197.27
# min                 0.00          0.00            0.00               0.00
# 25%                 1.00          1.00            0.00            5227.00
# 50%                 2.00          2.00            0.00            7500.00
# 75%                 3.00          2.00          310.00           16579.00
# max              3333.00        600.00       968348.00      7638115320.00
#
#        MiddleOrJuniorSchoolDistrict
# count                          0.00
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN

# %%
merged_residential_df.describe()
# Out:
#        OriginalListPrice    ListingKey   ClosePrice  Latitude  Longitude  \
# count          539409.00     540183.00    145580.00 460038.00  460038.00
# mean          1397125.34 1104798805.71   1202136.39     34.60    -118.46
# std           7357158.89   29883843.49   4292685.77      2.00       3.60
# min                 0.00 1018357250.00       525.00   -117.47    -159.48
# 25%            585000.00 1077378664.50    600000.00     33.74    -118.68
# 50%            849000.00 1104806266.00    855000.00     34.05    -118.03
# 75%           1389000.00 1126880009.50   1350000.00     34.47    -117.24
# max        1390000000.00 1157177805.00 820000000.00    737.00     329.00
#
#        LivingArea    ListPrice  DaysOnMarket  FireplacesTotal  \
# count   539627.00    540183.00     540183.00             0.00
# mean      1980.06   1312996.78         19.54              NaN
# std      23382.69   2346687.07         26.77              NaN
# min          0.00       100.00        -58.00              NaN
# 25%       1247.00    580000.00          5.00              NaN
# 50%       1669.00    840000.00         11.00              NaN
# 75%       2300.00   1375000.00         23.00              NaN
# max   17021321.00 195000000.00        731.00              NaN
#
#        AboveGradeFinishedArea  ListingKeyNumeric  TaxAnnualAmount  \
# count                    0.00          540183.00             0.00
# mean                      NaN      1104798805.71              NaN
# std                       NaN        29883843.49              NaN
# min                       NaN      1018357250.00              NaN
# 25%                       NaN      1077378664.50              NaN
# 50%                       NaN      1104806266.00              NaN
# 75%                       NaN      1126880009.50              NaN
# max                       NaN      1157177805.00              NaN
#
#        ParkingTotal  LotSizeAcres  YearBuilt  DaysOnMarket.1  \
# count     540163.00     495665.00  539244.00       540183.00
# mean           7.62         65.24    1979.60           19.54
# std         3529.17      12136.81      26.99           26.77
# min         -143.00          0.00    1776.00          -58.00
# 25%            2.00          0.12    1961.00            5.00
# 50%            2.00          0.17    1980.00           11.00
# 75%            3.00          0.31    2001.00           23.00
# max      2593669.00    4187292.00    2028.00          731.00
#
#        StreetNumberNumeric  LivingArea.1  BathroomsTotalInteger  \
# count            539333.00     539627.00              540128.00
# mean              11533.52       1980.06                   2.63
# std              281856.83      23382.69                   3.26
# min                   0.00          0.00                   0.00
# 25%                 975.00       1247.00                   2.00
# 50%                3271.00       1669.00                   2.00
# 75%               12060.00       2300.00                   3.00
# max            79547958.00   17021321.00                2208.00
#
#        BuyerAgencyCompensation  TaxYear  BuildingAreaTotal  BedroomsTotal  \
# count                 78993.00     0.00           47997.00      540035.00
# mean                    189.11      NaN            2445.25           3.22
# std                    2340.72      NaN            2249.24           1.19
# min                       0.00      NaN               0.00           0.00
# 25%                       2.00      NaN            1305.00           2.00
# 50%                       2.50      NaN            1824.00           3.00
# 75%                       2.50      NaN            2800.00           4.00
# max                  200000.00      NaN          123764.00          94.00
#
#        Longitude.1  ElementarySchoolDistrict  BelowGradeFinishedArea  \
# count    460038.00                      0.00                 3029.00
# mean       -118.46                       NaN                   87.07
# std           3.60                       NaN                  360.16
# min        -159.48                       NaN                    0.00
# 25%        -118.68                       NaN                    0.00
# 50%        -118.03                       NaN                    0.00
# 75%        -117.24                       NaN                    0.00
# max         329.00                       NaN                 5000.00
#
#        Latitude.1  ListPrice.1  CoveredSpaces   Stories  LotSizeArea  \
# count   460038.00    540183.00           0.00 445934.00    496504.00
# mean        34.60   1312996.78            NaN      1.37     46953.52
# std          2.00   2346687.07            NaN      0.48   2178789.61
# min       -117.47       100.00            NaN      1.00         0.00
# 25%         33.74    580000.00            NaN      1.00      5000.00
# 50%         34.05    840000.00            NaN      1.00      7196.00
# 75%         34.47   1375000.00            NaN      2.00     12051.00
# max        737.00 195000000.00            NaN      2.00 918742280.00
#
#        MainLevelBedrooms  GarageSpaces  AssociationFee  LotSizeSquareFeet  \
# count          294108.00     510192.00       410521.00          496329.00
# mean                2.05          1.85          270.78          411030.33
# std                 6.44          3.88         2369.07        20803367.94
# min                 0.00          0.00            0.00               0.00
# 25%                 1.00          1.00            0.00            5227.00
# 50%                 2.00          2.00          125.00            7405.00
# 75%                 3.00          2.00          400.00           13615.00
# max              3333.00        600.00       968348.00      7638115320.00
#
#        MiddleOrJuniorSchoolDistrict
# count                          0.00
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN

# %%
print("rows in merged df: " + str(len(merged_df)))
print("rows in merged residential df: " + str(len(merged_residential_df)))
print("difference in rows: " + str(len(merged_df) - len(merged_residential_df)))
# Out:
# rows in merged df: 852963
# rows in merged residential df: 540183
# difference in rows: 312780

# %%
# merged_residential_df.to_csv("listing_merged_residential.csv", index=False)
