# %%
import pandas as pd

pd.options.display.float_format = '{:1.2f}'.format
pd.options.display.max_columns = None

# %%
df = pd.read_csv("merged_listing.csv", encoding='latin-1')
# Out:
# C:\Users\Jamesb\AppData\Local\Temp\ipykernel_25316\2450504487.py:1: DtypeWarning: Columns (2,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("merged_listing.csv", encoding='latin-1')
